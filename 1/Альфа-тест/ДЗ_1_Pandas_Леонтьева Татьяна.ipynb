# %% [markdown]
# # Инструкция:

# %% [markdown]
# 1. Установите и импортируйте библиотеки:👇

# %%
# # Установка

# !pip install pandas
# !pip install clickhouse_driver

# %%
# Импорт

import pandas as pd
from clickhouse_driver import Client

# %% [markdown]
# 2. Запустите ячейку ниже с функцией создания датафрейма.

# %%
# Функция создания датафрейма

def create_dataframe(user, password, table_name='films'):
    client = Client('90.156.216.60', user=user, password=password, database='it_minimalist_CH')
    query = f'SELECT * FROM {table_name}'
    df = client.query_dataframe(query)
    return df

# %% [markdown]
# 3.  В ячейке ниже создается датафрейм в переменной `df`.
# <br>
#
# - Замените `'your_username'`, `'your_password'` на ваши учетные данные, которые получили на почту (у каждого своя учетная запись с индивидуальным доступом к БД Clickhouse).
# <br>
# - Как вы заметили в параметрах функции `create_dataframe`, по умолчанию датафрейм создатеся из таблицы `'films'`. Также в базе данных лежит таблица `'payments'`

# %%
films = create_dataframe(user='tanya25pm', password='klcemshu', table_name='films')

# %% [markdown]
# 4. Выведите датафрейм из таблицы films👇

# %%
films
# Out:
#     film_id                                          film_name  price_ticket  \
# 0         1                                  Побег из Шоушенка           190
# 1         2                                      Крёстный отец           190
# 2         3                                      Тёмный рыцарь           340
# 3         4                                    Крёстный отец 2           290
# 4         5                             12 разгневанных мужчин           290
# 5         6                                    Список Шиндлера           190
# 6         7                Властелин колец: Возвращение короля           290
# 7         8                                 Криминальное чтиво           290
# 8         9                   Властелин колец: Братство Кольца           290
# 9        10                              Хороший, плохой, злой           450
# 10       11                                       Форрест Гамп           190
# ...

# %% [markdown]
# 5. Создайте и выведите аналогичным образом датафрейм из таблицы `'payments'`👇

# %%
payments = create_dataframe(user='tanya25pm', password='klcemshu', table_name='payments')

# %% [markdown]
# # УРОК 1

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)

# %%
data = [
    ['Побег из Шоушенка', 1994],
    ['Крёстный отец', 1972],
    ['Тёмный рыцарь', 2008],
    ['Крёстный отец 2', 1974],
    ['12 разгневанных мужчин', 1957],
    ['Список Шиндлера', 1993]
]
columns = ['film_name', 'release_year']

# %%
pd.DataFrame(data=data, columns=columns)  #Создаем датафрейм
# Out:
#                 film_name  release_year
# 0       Побег из Шоушенка          1994
# 1           Крёстный отец          1972
# 2           Тёмный рыцарь          2008
# 3         Крёстный отец 2          1974
# 4  12 разгневанных мужчин          1957
# 5         Список Шиндлера          1993

# %%
df = pd.read_csv('data/films.csv')

# %% [markdown]
# # Обзор

# %%
df.head() #выводим 5 (по умолчанию) первых строк датафрейма
# Out:
#    film_id               film_name  price_ticket  release_year  \
# 0        1       Побег из Шоушенка           190          1994
# 1        2           Крёстный отец           190          1972
# 2        3           Тёмный рыцарь           340          2008
# 3        4         Крёстный отец 2           290          1974
# 4        5  12 разгневанных мужчин           290          1957
#
#               filmmaker                kind_film
# 0        Фрэнк Дарабонт                    драма
# 1  Фрэнсис Форд Коппола          детектив, драма
# 2       Кристофер Нолан  боевик, детектив, драма
# 3  Фрэнсис Форд Коппола          детектив, драма
# 4           Сидни Люмет          детектив, драма

# %% [markdown]
# ## Методы

# %%
df.tail() #выводим 5 (по умолчанию) последних строк датафрейма
# Out:
#     film_id                   film_name  price_ticket  release_year  \
# 44       45                    Харакири           290          1962
# 45       46         Подозрительные лица           190          1995
# 46       47                  Касабланка           450          1942
# 47       48                         1+1           290          2011
# 48       49  Новый кинотеатр «Парадизо»           190          1988
#
#                       filmmaker                                  kind_film
# 44               Масаки Кобаяси                 боевик, драма, фильм-тайна
# 45                Брайан Сингер               детектив, драма, фильм-тайна
# 46                 Майкл Кёртиц  драма, романтический фильм, военный фильм
# 47  Оливье Накаш, Эрик Толедано                байопик, кинокомедия, драма
# 48           Джузеппе Торнаторе                 драма, романтический фильм

# %%
df.sample(5) # вывод случайных 5 строк
# Out:
#     film_id                                          film_name  price_ticket  \
# 45       46                                Подозрительные лица           190
# 31       32                               Унесённые призраками           340
# 39       40                                         Отступники           190
# 0         1                                  Побег из Шоушенка           190
# 14       15  Звёздные войны. Эпизод V: Империя наносит отве...           190
#
#     release_year        filmmaker                                kind_film
# 45          1995    Брайан Сингер             детектив, драма, фильм-тайна
# 31          2001    Хаяо Миядзаки  мультфильм, приключение, семейный фильм
# 39          2006  Мартин Скорсезе                 детектив, драма, триллер
# 0           1994   Фрэнк Дарабонт                                    драма
# 14          1980    Ирвин Кершнер             боевик, приключение, фэнтези

# %%
df['filmmaker'] #выводим столбец с режиссерами фильмов
# Out:
# 0                                        Фрэнк Дарабонт
# 1                                  Фрэнсис Форд Коппола
# 2                                       Кристофер Нолан
# 3                                  Фрэнсис Форд Коппола
# 4                                           Сидни Люмет
# 5                                       Стивен Спилберг
# 6                                         Питер Джексон
# 7                                     Квентин Тарантино
# 8                                         Питер Джексон
# 9                                          Серджо Леоне
# 10                                       Роберт Земекис
# 11                                        Питер Джексон
# 12                                         Дэвид Финчер
# 13                                      Кристофер Нолан
# 14                                        Ирвин Кершнер
# 15                                Энди и Ларри Вачовски
# 16                                      Мартин Скорсезе
# ...

# %% [markdown]
# ## Аттрибуты

# %%
df.columns #получаем названия стобцов
# Out:
# Index(['film_id', 'film_name', 'price_ticket', 'release_year', 'filmmaker',
#        'kind_film'],
#       dtype='object')

# %%
df.shape # получаем размерность датафрейма в виде кортежа 49 строк, 6 столбцов
# Out:
# (49, 6)

# %%
print(f'Количество строк: {df.shape[0]}')
# Out:
# Количество строк: 49

# %%
df.dtypes #узнаем тип данных элементов датафрейма
# Out:
# film_id          int64
# film_name       object
# price_ticket     int64
# release_year     int64
# filmmaker       object
# kind_film       object
# dtype: object

# %% [markdown]
# ## Метод

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   film_id       49 non-null     int64
#  1   film_name     49 non-null     object
#  2   price_ticket  49 non-null     int64
#  3   release_year  49 non-null     int64
#  4   filmmaker     49 non-null     object
#  5   kind_film     49 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 2.4+ KB

# %% [markdown]
# # РАЗВЕДЫВАТЕЛЬНЫЙ АНАЛИЗ (EDA)

# %% [markdown]
# ## ИНДЕКСАЦИЯ

# %%
df.columns
# Out:
# Index(['film_id', 'film_name', 'price_ticket', 'release_year', 'filmmaker',
#        'kind_film'],
#       dtype='object')

# %%
df['release_year']
# Out:
# 0     1994
# 1     1972
# 2     2008
# 3     1974
# 4     1957
# 5     1993
# 6     2003
# 7     1994
# 8     2001
# 9     1966
# 10    1994
# 11    2002
# 12    1999
# 13    2010
# 14    1980
# 15    1999
# 16    1990
# 17    1975
# 18    1995
# 19    2014
# 20    2024
# 21    1946
# 22    1954
# 23    1991
# 24    1998
# 25    2002
# 26    1997
# 27    1999
# 28    1991
# 29    1977
# 30    1985
# 31    2001
# 32    2002
# 33    2019
# 34    1960
# 35    2023
# 36    2000
# 37    1994
# 38    1994
# 39    2006
# 40    1998
# 41    2014
# 42    2006
# 43    1988
# 44    1962
# 45    1995
# 46    1942
# 47    2011
# 48    1988
# Name: release_year, dtype: int64

# %%
df.head(6)
# Out:
#    film_id               film_name  price_ticket  release_year  \
# 0        1       Побег из Шоушенка           190          1994
# 1        2           Крёстный отец           190          1972
# 2        3           Тёмный рыцарь           340          2008
# 3        4         Крёстный отец 2           290          1974
# 4        5  12 разгневанных мужчин           290          1957
# 5        6         Список Шиндлера           190          1993
#
#               filmmaker                           kind_film
# 0        Фрэнк Дарабонт                               драма
# 1  Фрэнсис Форд Коппола                     детектив, драма
# 2       Кристофер Нолан             боевик, детектив, драма
# 3  Фрэнсис Форд Коппола                     детектив, драма
# 4           Сидни Люмет                     детектив, драма
# 5       Стивен Спилберг  байопик, драма, исторический фильм

# %%
type(df.loc[5])
# Out:
# pandas.core.series.Series

# %%
type(df['film_id'])
# Out:
# pandas.core.series.Series

# %%
df.loc[5]
# Out:
# film_id                                          6
# film_name                          Список Шиндлера
# price_ticket                                   190
# release_year                                  1993
# filmmaker                          Стивен Спилберг
# kind_film       байопик, драма, исторический фильм
# Name: 5, dtype: object

# %%
type(df.loc[5])
# Out:
# pandas.core.series.Series

# %%
list(df['film_name'])
# Out:
# ['Побег из Шоушенка',
#  'Крёстный отец',
#  'Тёмный рыцарь',
#  'Крёстный отец 2',
#  '12 разгневанных мужчин',
#  'Список Шиндлера',
#  'Властелин колец: Возвращение короля',
#  'Криминальное чтиво',
#  'Властелин колец: Братство Кольца',
#  'Хороший, плохой, злой',
#  'Форрест Гамп',
#  'Властелин колец: Две крепости',
#  'Бойцовский клуб',
#  'Начало',
#  'Звёздные войны. Эпизод V: Империя наносит ответный удар',
#  'Матрица',
#  'Славные парни',
#  'Пролетая над гнездом кукушки',
#  'Семь',
#  'Интерстеллар',
#  'Дюна: Часть вторая',
#  'Эта прекрасная жизнь',
#  'Семь самураев',
#  'Молчание ягнят',
#  'Спасти рядового Райана',
#  'Город Бога',
#  'Жизнь прекрасна',
#  'Зелёная миля',
#  'Терминатор 2: Судный день',
#  'Звёздные войны. Эпизод IV: Новая надежда',
#  'Назад в будущее',
#  'Унесённые призраками',
#  'Пианист',
#  'Паразиты',
#  'Психо',
#  'Человек-паук: Паутина вселенных',
#  'Гладиатор',
#  'Король Лев',
#  'Леон',
#  'Отступники',
# ...

# %%
list(df.loc[30])
# Out:
# [31,
#  'Назад в будущее',
#  340,
#  1985,
#  'Роберт Земекис',
#  'приключение, кинокомедия, научная фантастика']

# %%
df.head(6)
# Out:
#    film_id               film_name  price_ticket  release_year  \
# 0        1       Побег из Шоушенка           190          1994
# 1        2           Крёстный отец           190          1972
# 2        3           Тёмный рыцарь           340          2008
# 3        4         Крёстный отец 2           290          1974
# 4        5  12 разгневанных мужчин           290          1957
# 5        6         Список Шиндлера           190          1993
#
#               filmmaker                           kind_film
# 0        Фрэнк Дарабонт                               драма
# 1  Фрэнсис Форд Коппола                     детектив, драма
# 2       Кристофер Нолан             боевик, детектив, драма
# 3  Фрэнсис Форд Коппола                     детектив, драма
# 4           Сидни Люмет                     детектив, драма
# 5       Стивен Спилберг  байопик, драма, исторический фильм

# %%
df.loc[5, 'filmmaker']
# Out:
# 'Стивен Спилберг'

# %%
df_filtered = df.loc[[1, 5, 44, 0]]
df_filtered
# Out:
#     film_id          film_name  price_ticket  release_year  \
# 1         2      Крёстный отец           190          1972
# 5         6    Список Шиндлера           190          1993
# 44       45           Харакири           290          1962
# 0         1  Побег из Шоушенка           190          1994
#
#                filmmaker                           kind_film
# 1   Фрэнсис Форд Коппола                     детектив, драма
# 5        Стивен Спилберг  байопик, драма, исторический фильм
# 44        Масаки Кобаяси          боевик, драма, фильм-тайна
# 0         Фрэнк Дарабонт                               драма

# %%
df.loc[[1,8,13], ['kind_film', 'film_id', 'release_year']]
# Out:
#                                   kind_film  film_id  release_year
# 1                           детектив, драма        2          1972
# 8                боевик, приключение, драма        9          2001
# 13  боевик, приключение, научная фантастика       14          2010

# %%
df.loc[[4,7,16], :]
# Out:
#     film_id               film_name  price_ticket  release_year  \
# 4         5  12 разгневанных мужчин           290          1957
# 7         8      Криминальное чтиво           290          1994
# 16       17           Славные парни           190          1990
#
#             filmmaker                 kind_film
# 4         Сидни Люмет           детектив, драма
# 7   Квентин Тарантино           детектив, драма
# 16    Мартин Скорсезе  байопик, детектив, драма

# %%
df[['filmmaker', 'film_name']]
# Out:
#                                             filmmaker  \
# 0                                      Фрэнк Дарабонт
# 1                                Фрэнсис Форд Коппола
# 2                                     Кристофер Нолан
# 3                                Фрэнсис Форд Коппола
# 4                                         Сидни Люмет
# 5                                     Стивен Спилберг
# 6                                       Питер Джексон
# 7                                   Квентин Тарантино
# 8                                       Питер Джексон
# 9                                        Серджо Леоне
# 10                                     Роберт Земекис
# 11                                      Питер Джексон
# 12                                       Дэвид Финчер
# 13                                    Кристофер Нолан
# 14                                      Ирвин Кершнер
# 15                              Энди и Ларри Вачовски
# ...

# %%
df[:5]
# Out:
#    film_id               film_name  price_ticket  release_year  \
# 0        1       Побег из Шоушенка           190          1994
# 1        2           Крёстный отец           190          1972
# 2        3           Тёмный рыцарь           340          2008
# 3        4         Крёстный отец 2           290          1974
# 4        5  12 разгневанных мужчин           290          1957
#
#               filmmaker                kind_film
# 0        Фрэнк Дарабонт                    драма
# 1  Фрэнсис Форд Коппола          детектив, драма
# 2       Кристофер Нолан  боевик, детектив, драма
# 3  Фрэнсис Форд Коппола          детектив, драма
# 4           Сидни Люмет          детектив, драма

# %%
df.loc[:5]
# Out:
#    film_id               film_name  price_ticket  release_year  \
# 0        1       Побег из Шоушенка           190          1994
# 1        2           Крёстный отец           190          1972
# 2        3           Тёмный рыцарь           340          2008
# 3        4         Крёстный отец 2           290          1974
# 4        5  12 разгневанных мужчин           290          1957
# 5        6         Список Шиндлера           190          1993
#
#               filmmaker                           kind_film
# 0        Фрэнк Дарабонт                               драма
# 1  Фрэнсис Форд Коппола                     детектив, драма
# 2       Кристофер Нолан             боевик, детектив, драма
# 3  Фрэнсис Форд Коппола                     детектив, драма
# 4           Сидни Люмет                     детектив, драма
# 5       Стивен Спилберг  байопик, драма, исторический фильм

# %% [markdown]
# ## ЛОГИЧЕСКАЯ ИНДЕКСАЦИЯ

# %%
5 > 1
# Out:
# True

# %%
1 > 5
# Out:
# False

# %%
1 == 0
# Out:
# False

# %%
(5 > 1) is True
# Out:
# True

# %%
(5 > 1) is False
# Out:
# False

# %% [markdown]
# В одном выражении происходит фильтрация только по одному столбцу

# %%
type(df['release_year'])
# Out:
# pandas.core.series.Series

# %%
df['release_year'] > 1990
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15     True
# 16    False
# 17    False
# 18     True
# 19     True
# 20     True
# 21    False
# 22    False
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29    False
# 30    False
# 31     True
# 32     True
# 33     True
# 34    False
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43    False
# 44    False
# 45     True
# 46    False
# 47     True
# 48    False
# Name: release_year, dtype: bool

# %%
df_filtered = df[df['release_year'] > 2010]

# %%
df_filtered
# Out:
#     film_id                        film_name  price_ticket  release_year  \
# 19       20                     Интерстеллар           190          2014
# 20       21               Дюна: Часть вторая           190          2024
# 33       34                         Паразиты           450          2019
# 35       36  Человек-паук: Паутина вселенных           450          2023
# 41       42                      Одержимость           290          2014
# 47       48                              1+1           290          2011
#
#                                             filmmaker  \
# 19                                    Кристофер Нолан
# 20                                       Дени Вильнёв
# 33                                        Пон Чжун Хо
# 35  Жуакин Душ Сантуш[англ.], Кэмп Пауэрс[англ.], ...
# 41                                      Дамьен Шазель
# 47                        Оливье Накаш, Эрик Толедано
#
#                                  kind_film
# ...

# %%
df[df['release_year'] > 2010]['filmmaker']
# Out:
# 19                                      Кристофер Нолан
# 20                                         Дени Вильнёв
# 33                                          Пон Чжун Хо
# 35    Жуакин Душ Сантуш[англ.], Кэмп Пауэрс[англ.], ...
# 41                                        Дамьен Шазель
# 47                          Оливье Накаш, Эрик Толедано
# Name: filmmaker, dtype: object

# %%
print(f'Количество строк: {df[df["release_year"] > 2010].shape[0]}')
# Out:
# Количество строк: 6

# %%
df[df['release_year'] > 2010]['filmmaker'].count()
# Out:
# 6

# %%
len(df[df['release_year'] > 2010]['filmmaker'])
# Out:
# 6

# %%
df[df['release_year'] > 2010]['release_year'].max()
# Out:
# 2024

# %%
df[df['release_year'] > 2010]['release_year'].mean()
# Out:
# 2017.5

# %%
df[df['release_year'] > 2010]['price_ticket'].sum()
# Out:
# 1860

# %% [markdown]
# 1. Создать отфильтрованный датафрейм, в котором останутся только фильмы Стивена Спилберга.

# %%
df[df['filmmaker'] == 'Стивен Спилберг']
# Out:
#     film_id               film_name  price_ticket  release_year  \
# 5         6         Список Шиндлера           190          1993
# 24       25  Спасти рядового Райана           340          1998
#
#           filmmaker                           kind_film
# 5   Стивен Спилберг  байопик, драма, исторический фильм
# 24  Стивен Спилберг                драма, военный фильм

# %%
df.head(2)
# Out:
#    film_id          film_name  price_ticket  release_year  \
# 0        1  Побег из Шоушенка           190          1994
# 1        2      Крёстный отец           190          1972
#
#               filmmaker        kind_film
# 0        Фрэнк Дарабонт            драма
# 1  Фрэнсис Форд Коппола  детектив, драма

# %%
cond = df['filmmaker'] == 'Стивен Спилберг'

# %%
type(cond)
# Out:
# pandas.core.series.Series

# %%
df[cond]
# Out:
#     film_id               film_name  price_ticket  release_year  \
# 5         6         Список Шиндлера           190          1993
# 24       25  Спасти рядового Райана           340          1998
#
#           filmmaker                           kind_film
# 5   Стивен Спилберг  байопик, драма, исторический фильм
# 24  Стивен Спилберг                драма, военный фильм

# %% [markdown]
# 2. Найти средний год выхода фильмов жанра "боевик, приключение, драма".

# %%
df[df.kind_film == "боевик, приключение, драма"]['release_year'].mean()
# Out:
# 2006.0

# %% [markdown]
# 3. Посчитать количество фильмов с ценой билета больше 300 рублей и меньше. Сравнить.

# %%
df[df.price_ticket > 300].shape[0]
# Out:
# 17

# %%
g_300 = df[df.price_ticket > 300]['film_id'].count()
g_300
# Out:
# 17

# %%
l_e_300 = df[df.price_ticket <= 300]['film_id'].count()

# %%
g_300 < l_e_300
# Out:
# True

# %% [markdown]
# 4. Найдем год выхода самого позднего фильма Мартина Скорсезе.

# %%
df.head(2)
# Out:
#    film_id          film_name  price_ticket  release_year  \
# 0        1  Побег из Шоушенка           190          1994
# 1        2      Крёстный отец           190          1972
#
#               filmmaker        kind_film
# 0        Фрэнк Дарабонт            драма
# 1  Фрэнсис Форд Коппола  детектив, драма

# %%
scorsese_latest_film_year = df[df.filmmaker == 'Мартин Скорсезе']['release_year'].max()
scorsese_latest_film_year
# Out:
# 2006

# %% [markdown]
# # Домашнее задание 👨‍💻

# %% [markdown]
# #### 1. Создать датафрейм ваших любимых песен из двух столбцов (название песни, исполнитель) из 5 строк.

# %%
import pandas as pd

# %%
my_playlist = [
    ['Carnival of Rust', 'Poets of the fall'],
    ['Whisky in the jar', 'Metallica'],
    ['Paranoid', 'Black Sabbath'],
    ['War', 'Sum41'],
    ['Monsters', 'Shinedown'],
    ['Runaway', 'Del Shannon']
]
my_columns = ['song', 'singer']

pd.DataFrame(data=my_playlist, columns=my_columns)
# Out:
#                 song             singer
# 0   Carnival of Rust  Poets of the fall
# 1  Whisky in the jar          Metallica
# 2           Paranoid      Black Sabbath
# 3                War              Sum41
# 4           Monsters          Shinedown
# 5            Runaway        Del Shannon

# %% [markdown]
# #### 2. Считать csv файл `films.csv`

# %%
# your code
df = pd.read_csv('data/films.csv')

# %%
#df.head()

# %% [markdown]
# #### 3. Вывести количество строк датафрейма и общую информацию.

# %%
# your code
print(f'Количество строк: {df.shape[0]}')
# Out:
# Количество строк: 49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   film_id       49 non-null     int64
#  1   film_name     49 non-null     object
#  2   price_ticket  49 non-null     int64
#  3   release_year  49 non-null     int64
#  4   filmmaker     49 non-null     object
#  5   kind_film     49 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 2.4+ KB

# %% [markdown]
# #### 4. Вывести 5-ую строку датафрейма

# %%
# your code
df.iloc[4]
# Out:
# film_id                              5
# film_name       12 разгневанных мужчин
# price_ticket                       290
# release_year                      1957
# filmmaker                  Сидни Люмет
# kind_film              детектив, драма
# Name: 4, dtype: object

# %% [markdown]
# #### 5. Вывести столбец с ценой билета

# %%
# your code
df['price_ticket']
# Out:
# 0     190
# 1     190
# 2     340
# 3     290
# 4     290
# 5     190
# 6     290
# 7     290
# 8     290
# 9     450
# 10    190
# 11    290
# 12    190
# 13    190
# 14    190
# 15    290
# 16    190
# 17    340
# 18    190
# 19    190
# 20    190
# 21    340
# 22    450
# 23    450
# 24    340
# 25    190
# 26    190
# 27    450
# 28    290
# 29    190
# 30    340
# 31    340
# 32    340
# 33    450
# 34    290
# 35    450
# 36    290
# 37    190
# 38    340
# 39    190
# 40    290
# 41    290
# 42    450
# 43    450
# 44    290
# 45    190
# 46    450
# 47    290
# 48    190
# Name: price_ticket, dtype: int64

# %% [markdown]
# #### 6. Вывести с 10 по 30 строки для столбцов с названием фильма, датой релиза и режиссером.

# %%
# your code
df. loc[10:30, ['film_name', 'release_year', 'filmmaker']]
# Out:
#                                             film_name  release_year  \
# 10                                       Форрест Гамп          1994
# 11                      Властелин колец: Две крепости          2002
# 12                                    Бойцовский клуб          1999
# 13                                             Начало          2010
# 14  Звёздные войны. Эпизод V: Империя наносит отве...          1980
# 15                                            Матрица          1999
# 16                                      Славные парни          1990
# 17                       Пролетая над гнездом кукушки          1975
# 18                                               Семь          1995
# 19                                       Интерстеллар          2014
# 20                                 Дюна: Часть вторая          2024
# 21                               Эта прекрасная жизнь          1946
# 22                                      Семь самураев          1954
# ...

# %% [markdown]
# #### 7. Создайте датафрейм из столбцов с названиями фильмов и жанрами.

# %%
# your code
df[['film_name', 'kind_film']]
# Out:
#                                             film_name  \
# 0                                   Побег из Шоушенка
# 1                                       Крёстный отец
# 2                                       Тёмный рыцарь
# 3                                     Крёстный отец 2
# 4                              12 разгневанных мужчин
# 5                                     Список Шиндлера
# 6                 Властелин колец: Возвращение короля
# 7                                  Криминальное чтиво
# 8                    Властелин колец: Братство Кольца
# 9                               Хороший, плохой, злой
# 10                                       Форрест Гамп
# 11                      Властелин колец: Две крепости
# 12                                    Бойцовский клуб
# 13                                             Начало
# 14  Звёздные войны. Эпизод V: Империя наносит отве...
# 15                                            Матрица
# ...

# %% [markdown]
# #### 8. Отфильтруйте датафрейм, оставив в нем фильмы, вышедшие в 21-ом веке.

# %%
# your code
df[df['release_year'] > 2000]
# Out:
#     film_id                            film_name  price_ticket  release_year  \
# 2         3                        Тёмный рыцарь           340          2008
# 6         7  Властелин колец: Возвращение короля           290          2003
# 8         9     Властелин колец: Братство Кольца           290          2001
# 11       12        Властелин колец: Две крепости           290          2002
# 13       14                               Начало           190          2010
# 19       20                         Интерстеллар           190          2014
# 20       21                   Дюна: Часть вторая           190          2024
# 25       26                           Город Бога           190          2002
# 31       32                 Унесённые призраками           340          2001
# 32       33                              Пианист           340          2002
# 33       34                             Паразиты           450          2019
# ...

# %% [markdown]
# #### 9. Отфильтруйте датафрейм, оставив только фильмы Кристофера Нолана.

# %%
# your code
df[df['filmmaker'] == 'Кристофер Нолан']
# Out:
#     film_id      film_name  price_ticket  release_year        filmmaker  \
# 2         3  Тёмный рыцарь           340          2008  Кристофер Нолан
# 13       14         Начало           190          2010  Кристофер Нолан
# 19       20   Интерстеллар           190          2014  Кристофер Нолан
# 42       43        Престиж           450          2006  Кристофер Нолан
#
#                                   kind_film
# 2                   боевик, детектив, драма
# 13  боевик, приключение, научная фантастика
# 19   приключение, драма, научная фантастика
# 42   драма, фильм-тайна, научная фантастика

# %% [markdown]
# #### 10. Проведите мини-анализ с помощью изученных на первом уроке методов, выяснив, чьих фильмов больше — Роберта Земекиса или Дэвида Финчера?
#
# Порядок действий:
# 1. Провести фильтрацию с помощью логической индексации и посчитать количество строк удобным вам удобным способом (с помощью метода count() или аттрибута shape)
# 2. Записать в отдельные переменные и сравнить
# 3. Вывести результат на экран

# %%
# your code
df_Zemeckis =df[df['filmmaker'] == 'Роберт Земекис'].shape[0]
print(f'Количество фильмов Роберта Земекиса: {df_Zemeckis}')
df_Fincher =df[df['filmmaker'] == 'Дэвид Финчер'].shape[0]
print(f'Количество фильмов Дэвида Финчера: {df_Fincher}')
if df_Zemeckis == df_Fincher:
    print("У обоих режиссеров одинаковое количество фильмов")
# Out:
# Количество фильмов Роберта Земекиса: 2
# Количество фильмов Дэвида Финчера: 2
# У обоих режиссеров одинаковое количество фильмов

# %% [markdown]
# #### 11. Посчитайте количество фильмов в жанре "драма" и количество фильмов в жанре "детектив, драма".
# Ответить на вопрос, какому из этих жанров отдается предпочтение в нашем кинотеатре?

# %%
# your code
df[df['kind_film'] == 'драма'].shape[0]
df[df['kind_film'] == 'детектив, драма'].shape[0]

print(f"Количество фильмов в жанре \"детектив, драма\": {df[df['kind_film'] == 'детектив, драма'].shape[0]}")
print(f"Количество фильмов в жанре \"драма\": {df[df['kind_film'] == 'драма'].shape[0]}")

if df[df['kind_film'] == 'драма'].shape[0] > df[df['kind_film'] == 'детектив, драма'].shape[0]:
    print('Предпочтение отдается фильмам в жанре "драма"')
elif df[df['kind_film'] == 'драма'].shape[0] < df[df['kind_film'] == 'детектив, драма'].shape[0]    :
    print('Предпочтение отдается фильмам в жанре "детектив, драма"')
else:
    print("Зрители одинаково любят фильмы обоих жанров")
# Out:
# Количество фильмов в жанре "детектив, драма": 6
# Количество фильмов в жанре "драма": 3
# Предпочтение отдается фильмам в жанре "детектив, драма"

# %% [markdown]
# #### 12. Найти год выхода самого старого фильма Питера Джексона.

# %%
# your code
df[df['filmmaker'] == 'Питер Джексон']['release_year'].min()
# Out:
# 2001

# %% [markdown]
# #### 13. Найти среднюю цену билета фильмов, вышедших с 2000 по 2020 года.

# %%
# your code
df[(df['release_year'] >= 2000) & (df['release_year'] <= 2020)]['price_ticket'].mean()
# Out:
# 294.6666666666667
